# %% [markdown]
# ### Implementing Linear Regression using a single Neuron

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
os.chdir("/Users/rahuljantwal/Desktop/git/LinearRegressionANN")
bike_df = pd.read_csv("./data/Bike-Sharing-Dataset/day.csv",delimiter=',')
N = np.shape(bike_df)[0]

# %%
bike_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
sns.distplot(bike_df['cnt'])

# %%
sns.distplot(np.log(bike_df['atemp']))

# %%
X = bike_df['atemp']
Y = bike_df['cnt']

# %%
def cost_function(X, Y, weight, bias):
    total_error = 0.0
    for i in range(len(X)):
        total_error += (Y[i] - (weight*X[i] + bias))**2
    return total_error / len(X)

# %%
def update_weights(X, Y, weight, bias, learning_rate):
    weight_deriv = 0
    bias_deriv = 0

    for i in range(len(X)):
        # Calculate partial derivatives
        # -2x(y - (mx + b))
        weight_deriv += -2*X[i] * (Y[i] - (weight*X[i] + bias))

        # -2(y - (mx + b))
        bias_deriv += -2*(Y[i] - (weight*X[i] + bias))

    # We subtract because the derivatives point in direction of steepest ascent
    weight -= (weight_deriv / len(X)) * learning_rate
    bias -= (bias_deriv / len(X)) * learning_rate

    return weight, bias

# %%
def train(X, Y, weight, bias, learning_rate, iters):
    cost_history = []
    weight_history = []
    bias_history = []
    for i in range(iters):
        weight,bias = update_weights(X, Y, weight, bias, learning_rate)
        #Calculate cost for auditing purposes
        cost = cost_function(X, Y, weight,bias)
        cost_history.append(cost)
        weight_history.append(weight)
        bias_history.append(weight)
        # Log Progress
        if i % 500 == 0:
            print ("iter: "+str(i) + " cost: "+str(cost) + " weight: "+str(weight) + " bias: "+str(bias))

    return weight, bias, cost_history, weight_history, bias_history

# %%
w = np.array([0, 0])
up_weight, up_bias, cost_hist, weight_hist, bias_hist = train(X,Y,w[0],w[1],0.05,6000)
# Out:
# iter: 0 cost: 19204391.850206915 weight: 233.56046000850867 bias: 450.43488372093026
# iter: 500 cost: 2354773.9783503874 weight: 5567.861926608759 bias: 1883.427472559045
# iter: 1000 cost: 2266677.73223581 weight: 6844.5660385588435 bias: 1264.4721729230762
# iter: 1500 cost: 2256502.5572185717 weight: 7278.458894625523 bias: 1054.1178079430435
# iter: 2000 cost: 2255327.31773678 weight: 7425.919068665487 bias: 982.628059180609
# iter: 2500 cost: 2255191.5767950034 weight: 7476.03398211443 bias: 958.3319901230403
# iter: 3000 cost: 2255175.8986259503 weight: 7493.065730288785 bias: 950.0748765946124
# iter: 3500 cost: 2255174.087786999 weight: 7498.854036122538 bias: 947.2686644596471
# iter: 4000 cost: 2255173.8786338945 weight: 7500.821214364141 bias: 946.314962355477
# iter: 4500 cost: 2255173.854476572 weight: 7501.489767537624 bias: 945.9908429875337
# iter: 5000 cost: 2255173.8516863873 weight: 7501.716977932856 bias: 945.880689760216
# iter: 5500 cost: 2255173.8513641185 weight: 7501.794196269032 bias: 945.8432537576546

# %%
tt = np.linspace(np.min(bike_df['atemp']), np.max(bike_df['atemp']), 100)
bf_line = up_bias+up_weight*tt

# %%
plt.plot(bike_df['atemp'],bike_df['cnt'], 'ro', tt, bf_line, 'r-')
plt.xlabel('atemp (Normalized)')
plt.ylabel('cnt')
plt.title('ANN Regression on 1D Bike Share data')
 
plt.savefig('bike.png')
 
plt.show()

# %%
print(up_weight, up_bias)
# Out:
# 7501.8204100276125 945.8305451397024

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(bike_df['atemp'].values.reshape(-1,1),bike_df['cnt'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regr.score(bike_df['atemp'].values.reshape(-1,1),bike_df['cnt'])
# Out:
# 0.3982439175261369

# %%
tt = np.linspace(np.min(bike_df['atemp']), np.max(bike_df['atemp']), 100)
bf_line = regr.intercept_+regr.coef_*tt
plt.plot(bike_df['atemp'],bike_df['cnt'], 'ro', tt, bf_line, 'r-')
plt.xlabel('atemp (Normalized)')
plt.ylabel('cnt')
plt.title('ANN Regression on 1D Bike Share data')
 
plt.savefig('bike.png')
 
plt.show()

# %%
print(regr.coef_, regr.intercept_)
# Out:
# [7501.83394952] 945.823981098491
